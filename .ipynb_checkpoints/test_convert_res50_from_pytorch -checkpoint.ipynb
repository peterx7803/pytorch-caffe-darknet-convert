# %% [markdown]
# # Test Resnet-50 accuracy convert from PyTorch

# %% [markdown]
# ### 1. Setup
#
# * First, set up Python, `numpy`, and `matplotlib`.

# %%
# set up Python environment: numpy for numerical routines, and matplotlib for plotting
import numpy as np
import matplotlib.pyplot as plt
import os
# display plots in this notebook
# %matplotlib inline

# set display defaults
plt.rcParams['figure.figsize'] = (10, 10)        # large images
plt.rcParams['image.interpolation'] = 'nearest'  # don't interpolate: show square pixels
plt.rcParams['image.cmap'] = 'gray'  # use grayscale output rather than a (potentially misleading) color heatmap

# %% [markdown]
# * Load `caffe`.

# %%
# The caffe module needs to be on the Python path;
#  we'll add it here explicitly.
import sys
caffe_root = '/home/peter/caffe/'  # this file should be run from {caffe_root}/examples (otherwise change this line)
sys.path.insert(0, caffe_root + 'python')

import caffe
# If you get "No module named _caffe", either you have not built pycaffe or you have the wrong path.

# %% [markdown]
# ### 2. Load net and set up input preprocessing
#
# * Set Caffe to CPU mode and load the net from disk.

# %%
caffe.set_mode_cpu()

model_def =  'resnet50-pytorch2caffe.prototxt'
model_weights = 'resnet50-pytorch2caffe.caffemodel' 

net = caffe.Net(model_def,      # defies the structure of the model
                model_weights,  # contains the trained weights
                caffe.TEST)     # use test mode (e.g., don't perform dropout)

# %% [markdown]
# * Set up input preprocessing. (We'll use Caffe's `caffe.io.Transformer` to do this, but this step is independent of other parts of Caffe, so any custom preprocessing code may be used).
#
#     Our default CaffeNet is configured to take images in BGR format. Values are expected to start in the range [0, 255] and then have the mean ImageNet pixel value subtracted from them. In addition, the channel dimension is expected as the first (_outermost_) dimension.
#
#     As matplotlib will load images with values in the range [0, 1] in RGB format with the channel as the _innermost_ dimension, we are arranging for the needed transformations here.

# %% [markdown]
# ### 3. CPU classification
#
# * Now we're ready to perform classification. Even though we'll only classify one image, we'll set a batch size of 50 to demonstrate batching.

# %%
# load the mean ImageNet image (as distributed with Caffe) for subtraction
#mu = np.load(caffe_root + 'python/caffe/imagenet/ilsvrc_2012_mean.npy')
#mu = mu.mean(1).mean(1)  # average over pixels to obtain the mean (BGR) pixel values
#print 'mean-subtracted values:', zip('BGR', mu)
# create transformer for the input called 'data'
transformer = caffe.io.Transformer({'data': net.blobs['data'].data.shape})

transformer.set_transpose('data', (2,0,1))  # move image channels to outermost dimension
#transformer.set_mean('data', mu)            # subtract the dataset-mean value in each channel
#transformer.set_raw_scale('data', 255)

#transformer.set_var('data', var)
#transformer.set_channel_swap('data', (2,1,0))  # swap channels from RGB to BGR

# %%
# set the size of the input (we can skip this if we're happy
#  with the default; we can also change it later, e.g., for different batch sizes)
net.blobs['data'].reshape(1,        # batch size
                          3,         # 3-channel (BGR) images
                          224, 224)  # image size is 227x227

# %% [markdown]
# * Load an image (that comes with Caffe) and perform the preprocessing we've set up.

# %%
# copy the image data into the memory allocated for the net
image = caffe.io.load_image('data/dog.jpg')

mu = [ 0.485, 0.456, 0.406] # RGB 
#mu = [ 0.406, 0.456, 0.485] # BGR 
#print mu
image = image - mu
print 'Image dimension=', image.shape
#print image
#image = image /255
std = [ 0.229, 0.224, 0.225]
#print std[0]
image[:,:,0] = image[:,:,0]/std[0]  #RGB std by pytorch imagenet example
image[:,:,1] = image[:,:,1]/std[1]  #RGB std by pytorch imagenet example
image[:,:,2] = image[:,:,2]/std[2]  #RGB std by pytorch imagenet example

#image = image[:,:,0:3]  / [ 0.225, 0.224, 0.229]  #BGR std by pytorch imagenet example
#print image[0:5,0,0]
transformed_image = transformer.preprocess('data', image)
#plt.imshow(image)
# Out:
# Image dimension= (576, 768, 3)
# /usr/local/lib/python2.7/dist-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "

# %%
net.blobs['data'].data[...] = transformed_image

### perform classification
output = net.forward()

output_prob = output['AddmmBackward190'][0]  # the output probability vector for the first image in the batch

# %%
# load ImageNet labels
labels_file = caffe_root + 'data/ilsvrc12/synset_words.txt'
if not os.path.exists(labels_file):
    # !../data/ilsvrc12/get_ilsvrc_aux.sh
    
    
    
labels = np.loadtxt(labels_file, str, delimiter='\t')

#print 'output label:', labels[output_prob.argmax()]

# %%
# sort top five predictions from softmax output
top_inds = output_prob.argsort()[::-1][:5]  # reverse sort and take five largest items
print top_inds

print 'probabilities and labels:'
zip(output_prob[top_inds], labels[top_inds])
# Out:
# [249 248 250 235 537]
# probabilities and labels:
# [(12.144663, 'n02110063 malamute, malemute, Alaskan malamute'),
#  (11.67174, 'n02109961 Eskimo dog, husky'),
#  (11.052471, 'n02110185 Siberian husky'),
#  (9.0667601,
#   'n02106662 German shepherd, German shepherd dog, German police dog, alsatian'),
#  (8.5264196, 'n03218198 dogsled, dog sled, dog sleigh')]

# %% [markdown]
# * We see that less confident predictions are sensible.

# %% [markdown]
# ### 4. Examining intermediate output
#
# * A net is not just a black box; let's take a look at some of the parameters and intermediate activations.
#
# First we'll see how to read out the structure of the net in terms of activation and parameter shapes.
#
# * For each layer, let's look at the activation shapes, which typically have the form `(batch_size, channel_dim, height, width)`.
#
#     The activations are exposed as an `OrderedDict`, `net.blobs`.

# %%
# for each layer, show the output shape
for layer_name, blob in net.blobs.iteritems():
    print layer_name + '\t' + str(blob.data.shape)
# Out:
# data	(1, 3, 224, 224)
# ConvNdBackward1	(1, 64, 112, 112)
# BatchNormBackward2	(1, 64, 112, 112)
# MaxPool2dBackward4	(1, 64, 56, 56)
# MaxPool2dBackward4_MaxPool2dBackward4_0_split_0	(1, 64, 56, 56)
# MaxPool2dBackward4_MaxPool2dBackward4_0_split_1	(1, 64, 56, 56)
# ConvNdBackward5	(1, 64, 56, 56)
# BatchNormBackward6	(1, 64, 56, 56)
# ConvNdBackward8	(1, 64, 56, 56)
# BatchNormBackward9	(1, 64, 56, 56)
# ConvNdBackward11	(1, 256, 56, 56)
# BatchNormBackward12	(1, 256, 56, 56)
# ConvNdBackward14	(1, 256, 56, 56)
# BatchNormBackward15	(1, 256, 56, 56)
# AddBackward16	(1, 256, 56, 56)
# AddBackward16_ThresholdBackward17_0_split_0	(1, 256, 56, 56)
# AddBackward16_ThresholdBackward17_0_split_1	(1, 256, 56, 56)
# ConvNdBackward18	(1, 64, 56, 56)
# BatchNormBackward19	(1, 64, 56, 56)
# ConvNdBackward21	(1, 64, 56, 56)
# BatchNormBackward22	(1, 64, 56, 56)
# ConvNdBackward24	(1, 256, 56, 56)
# BatchNormBackward25	(1, 256, 56, 56)
# AddBackward27	(1, 256, 56, 56)
# AddBackward27_ThresholdBackward28_0_split_0	(1, 256, 56, 56)
# AddBackward27_ThresholdBackward28_0_split_1	(1, 256, 56, 56)
# ConvNdBackward29	(1, 64, 56, 56)
# BatchNormBackward30	(1, 64, 56, 56)
# ConvNdBackward32	(1, 64, 56, 56)
# BatchNormBackward33	(1, 64, 56, 56)
# ConvNdBackward35	(1, 256, 56, 56)
# BatchNormBackward36	(1, 256, 56, 56)
# AddBackward38	(1, 256, 56, 56)
# AddBackward38_ThresholdBackward39_0_split_0	(1, 256, 56, 56)
# AddBackward38_ThresholdBackward39_0_split_1	(1, 256, 56, 56)
# ConvNdBackward40	(1, 128, 56, 56)
# BatchNormBackward41	(1, 128, 56, 56)
# ConvNdBackward43	(1, 128, 28, 28)
# BatchNormBackward44	(1, 128, 28, 28)
# ConvNdBackward46	(1, 512, 28, 28)
# BatchNormBackward47	(1, 512, 28, 28)
# ConvNdBackward49	(1, 512, 28, 28)
# BatchNormBackward50	(1, 512, 28, 28)
# AddBackward51	(1, 512, 28, 28)
# AddBackward51_ThresholdBackward52_0_split_0	(1, 512, 28, 28)
# AddBackward51_ThresholdBackward52_0_split_1	(1, 512, 28, 28)
# ConvNdBackward53	(1, 128, 28, 28)
# BatchNormBackward54	(1, 128, 28, 28)
# ConvNdBackward56	(1, 128, 28, 28)
# BatchNormBackward57	(1, 128, 28, 28)
# ConvNdBackward59	(1, 512, 28, 28)
# BatchNormBackward60	(1, 512, 28, 28)
# AddBackward62	(1, 512, 28, 28)
# AddBackward62_ThresholdBackward63_0_split_0	(1, 512, 28, 28)
# AddBackward62_ThresholdBackward63_0_split_1	(1, 512, 28, 28)
# ConvNdBackward64	(1, 128, 28, 28)
# BatchNormBackward65	(1, 128, 28, 28)
# ConvNdBackward67	(1, 128, 28, 28)
# BatchNormBackward68	(1, 128, 28, 28)
# ConvNdBackward70	(1, 512, 28, 28)
# BatchNormBackward71	(1, 512, 28, 28)
# AddBackward73	(1, 512, 28, 28)
# AddBackward73_ThresholdBackward74_0_split_0	(1, 512, 28, 28)
# AddBackward73_ThresholdBackward74_0_split_1	(1, 512, 28, 28)
# ConvNdBackward75	(1, 128, 28, 28)
# BatchNormBackward76	(1, 128, 28, 28)
# ConvNdBackward78	(1, 128, 28, 28)
# BatchNormBackward79	(1, 128, 28, 28)
# ConvNdBackward81	(1, 512, 28, 28)
# BatchNormBackward82	(1, 512, 28, 28)
# AddBackward84	(1, 512, 28, 28)
# AddBackward84_ThresholdBackward85_0_split_0	(1, 512, 28, 28)
# AddBackward84_ThresholdBackward85_0_split_1	(1, 512, 28, 28)
# ConvNdBackward86	(1, 256, 28, 28)
# BatchNormBackward87	(1, 256, 28, 28)
# ConvNdBackward89	(1, 256, 14, 14)
# BatchNormBackward90	(1, 256, 14, 14)
# ConvNdBackward92	(1, 1024, 14, 14)
# BatchNormBackward93	(1, 1024, 14, 14)
# ConvNdBackward95	(1, 1024, 14, 14)
# BatchNormBackward96	(1, 1024, 14, 14)
# AddBackward97	(1, 1024, 14, 14)
# AddBackward97_ThresholdBackward98_0_split_0	(1, 1024, 14, 14)
# AddBackward97_ThresholdBackward98_0_split_1	(1, 1024, 14, 14)
# ConvNdBackward99	(1, 256, 14, 14)
# BatchNormBackward100	(1, 256, 14, 14)
# ConvNdBackward102	(1, 256, 14, 14)
# BatchNormBackward103	(1, 256, 14, 14)
# ConvNdBackward105	(1, 1024, 14, 14)
# BatchNormBackward106	(1, 1024, 14, 14)
# AddBackward108	(1, 1024, 14, 14)
# AddBackward108_ThresholdBackward109_0_split_0	(1, 1024, 14, 14)
# AddBackward108_ThresholdBackward109_0_split_1	(1, 1024, 14, 14)
# ConvNdBackward110	(1, 256, 14, 14)
# BatchNormBackward111	(1, 256, 14, 14)
# ConvNdBackward113	(1, 256, 14, 14)
# BatchNormBackward114	(1, 256, 14, 14)
# ConvNdBackward116	(1, 1024, 14, 14)
# BatchNormBackward117	(1, 1024, 14, 14)
# AddBackward119	(1, 1024, 14, 14)
# AddBackward119_ThresholdBackward120_0_split_0	(1, 1024, 14, 14)
# AddBackward119_ThresholdBackward120_0_split_1	(1, 1024, 14, 14)
# ConvNdBackward121	(1, 256, 14, 14)
# BatchNormBackward122	(1, 256, 14, 14)
# ConvNdBackward124	(1, 256, 14, 14)
# BatchNormBackward125	(1, 256, 14, 14)
# ConvNdBackward127	(1, 1024, 14, 14)
# BatchNormBackward128	(1, 1024, 14, 14)
# AddBackward130	(1, 1024, 14, 14)
# AddBackward130_ThresholdBackward131_0_split_0	(1, 1024, 14, 14)
# AddBackward130_ThresholdBackward131_0_split_1	(1, 1024, 14, 14)
# ConvNdBackward132	(1, 256, 14, 14)
# BatchNormBackward133	(1, 256, 14, 14)
# ConvNdBackward135	(1, 256, 14, 14)
# BatchNormBackward136	(1, 256, 14, 14)
# ConvNdBackward138	(1, 1024, 14, 14)
# BatchNormBackward139	(1, 1024, 14, 14)
# AddBackward141	(1, 1024, 14, 14)
# AddBackward141_ThresholdBackward142_0_split_0	(1, 1024, 14, 14)
# AddBackward141_ThresholdBackward142_0_split_1	(1, 1024, 14, 14)
# ConvNdBackward143	(1, 256, 14, 14)
# BatchNormBackward144	(1, 256, 14, 14)
# ConvNdBackward146	(1, 256, 14, 14)
# BatchNormBackward147	(1, 256, 14, 14)
# ConvNdBackward149	(1, 1024, 14, 14)
# BatchNormBackward150	(1, 1024, 14, 14)
# AddBackward152	(1, 1024, 14, 14)
# AddBackward152_ThresholdBackward153_0_split_0	(1, 1024, 14, 14)
# AddBackward152_ThresholdBackward153_0_split_1	(1, 1024, 14, 14)
# ConvNdBackward154	(1, 512, 14, 14)
# BatchNormBackward155	(1, 512, 14, 14)
# ConvNdBackward157	(1, 512, 7, 7)
# BatchNormBackward158	(1, 512, 7, 7)
# ConvNdBackward160	(1, 2048, 7, 7)
# BatchNormBackward161	(1, 2048, 7, 7)
# ConvNdBackward163	(1, 2048, 7, 7)
# BatchNormBackward164	(1, 2048, 7, 7)
# AddBackward165	(1, 2048, 7, 7)
# AddBackward165_ThresholdBackward166_0_split_0	(1, 2048, 7, 7)
# AddBackward165_ThresholdBackward166_0_split_1	(1, 2048, 7, 7)
# ConvNdBackward167	(1, 512, 7, 7)
# BatchNormBackward168	(1, 512, 7, 7)
# ConvNdBackward170	(1, 512, 7, 7)
# BatchNormBackward171	(1, 512, 7, 7)
# ConvNdBackward173	(1, 2048, 7, 7)
# BatchNormBackward174	(1, 2048, 7, 7)
# AddBackward176	(1, 2048, 7, 7)
# AddBackward176_ThresholdBackward177_0_split_0	(1, 2048, 7, 7)
# AddBackward176_ThresholdBackward177_0_split_1	(1, 2048, 7, 7)
# ConvNdBackward178	(1, 512, 7, 7)
# BatchNormBackward179	(1, 512, 7, 7)
# ConvNdBackward181	(1, 512, 7, 7)
# BatchNormBackward182	(1, 512, 7, 7)
# ConvNdBackward184	(1, 2048, 7, 7)
# BatchNormBackward185	(1, 2048, 7, 7)
# AddBackward187	(1, 2048, 7, 7)
# AvgPool2dBackward189	(1, 2048, 1, 1)
# AddmmBackward190	(1, 1000)

# %% [markdown]
# * Since we're dealing with four-dimensional data here, we'll define a helper function for visualizing sets of rectangular heatmaps.

# %%
def vis_square(data):
    """Take an array of shape (n, height, width) or (n, height, width, 3)
       and visualize each (height, width) thing in a grid of size approx. sqrt(n) by sqrt(n)"""
    
    # normalize data for display
    data = (data - data.min()) / (data.max() - data.min())
    
    # force the number of filters to be square
    n = int(np.ceil(np.sqrt(data.shape[0])))
    padding = (((0, n ** 2 - data.shape[0]),
               (0, 1), (0, 1))                 # add some space between filters
               + ((0, 0),) * (data.ndim - 3))  # don't pad the last dimension (if there is one)
    data = np.pad(data, padding, mode='constant', constant_values=1)  # pad with ones (white)
    
    # tile the filters into an image
    data = data.reshape((n, n) + data.shape[1:]).transpose((0, 2, 1, 3) + tuple(range(4, data.ndim + 1)))
    data = data.reshape((n * data.shape[1], n * data.shape[3]) + data.shape[4:])
    
    plt.imshow(data); plt.axis('off')

# %%
# the parameters are a list of [weights, biases]
filters = net.params['ConvNdBackward1'][0].data
vis_square(filters.transpose(0, 2, 3, 1))

# %%
feat = net.blobs['ConvNdBackward1'].data[0, :36]
vis_square(feat)

# %%
feat = net.blobs['MaxPool2dBackward4'].data[0]
vis_square(feat)

# %%
feat = net.blobs['AddmmBackward190'].data[0]
plt.subplot(2, 1, 1)
plt.plot(feat.flat)
plt.subplot(2, 1, 2)
_ = plt.hist(feat.flat[feat.flat > 0], bins=100)

# %% [markdown]
# Note the cluster of strong predictions; the labels are sorted semantically. The top peaks correspond to the top predicted labels, as shown above.

# %% [markdown]
# ### 6. Test Original Pytorch Resnet50

# %%
import sys
sys.path.append('/data/temp/caffe/python')
from collections import OrderedDict
import torch.nn as nn
import torch.nn.functional as F
import torch
import numpy as np
from torch.autograd import Variable
import torchvision
from visualize import make_dot
import torch.utils.data as data
from PIL import Image
from torchvision import transforms
m = torchvision.models.resnet50(pretrained=True)
#m.classifier.add_module('softmax', torch.nn.Softmax())
m.eval() # very important here, otherwise batchnorm running_mean, running_var will be incorrect
#input_var = Variable(torch.rand(1, 3, 224, 224))
# Out:
# ResNet (
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#   (relu): ReLU (inplace)
#   (maxpool): MaxPool2d (size=(3, 3), stride=(2, 2), padding=(1, 1), dilation=(1, 1))
#   (layer1): Sequential (
#     (0): Bottleneck (
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#       (relu): ReLU (inplace)
#       (downsample): Sequential (
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#       )
#     )
#     (1): Bottleneck (
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#       (relu): ReLU (inplace)
#     )
#     (2): Bottleneck (
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#       (relu): ReLU (inplace)
#     )
#   )
#   (layer2): Sequential (
#     (0): Bottleneck (
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#       (relu): ReLU (inplace)
#       (downsample): Sequential (
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#       )
#     )
#     (1): Bottleneck (
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#       (relu): ReLU (inplace)
#     )
#     (2): Bottleneck (
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#       (relu): ReLU (inplace)
#     )
#     (3): Bottleneck (
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#       (relu): ReLU (inplace)
#     )
#   )
#   (layer3): Sequential (
#     (0): Bottleneck (
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#       (relu): ReLU (inplace)
#       (downsample): Sequential (
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#       )
#     )
#     (1): Bottleneck (
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#       (relu): ReLU (inplace)
#     )
#     (2): Bottleneck (
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#       (relu): ReLU (inplace)
#     )
#     (3): Bottleneck (
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#       (relu): ReLU (inplace)
#     )
#     (4): Bottleneck (
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#       (relu): ReLU (inplace)
#     )
#     (5): Bottleneck (
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#       (relu): ReLU (inplace)
#     )
#   )
#   (layer4): Sequential (
#     (0): Bottleneck (
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True)
#       (relu): ReLU (inplace)
#       (downsample): Sequential (
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True)
#       )
#     )
#     (1): Bottleneck (
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True)
#       (relu): ReLU (inplace)
#     )
#     (2): Bottleneck (
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True)
#       (relu): ReLU (inplace)
#     )
#   )
#   (avgpool): AvgPool2d (size=7, stride=7, padding=0, ceil_mode=False, count_include_pad=True)
#   (fc): Linear (2048 -> 1000)
# )

# %%
#from argparse.test_options import TestOptions

# Load image
real = Image.open('data/dog.jpg').convert('RGB')
print real
#I = torch.from_numpy(real.transpose([2,0,1])).float()

normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                     std=[0.229, 0.224, 0.225])
preprocess = transforms.Compose([
transforms.Scale([224,224]),
#transforms.CenterCrop(224),
transforms.ToTensor(),
normalize,
])  

plt.imshow(real)
# Out:
# <PIL.Image.Image image mode=RGB size=768x576 at 0x7FE59211DC10>

# %%
# Load input
input_A = preprocess(real)
print input_A[0,0:5,0]
input_A = input_A.unsqueeze(0)
input_A = Variable(input_A)
output = m.forward(input_A)
# Out:
# -1.1075
# -1.1075
# -1.0904
# -1.0904
# -1.0904
# [torch.FloatTensor of size 5]

# %%
# Pytorch result
_, pred = torch.sort(output.data,1,True)
print('TOP 10 classes: ',pred[0,0:10] , _[0,0:10])
#print output.data.sort()
# Out:
# ('TOP 10 classes: ',
#  249
#  248
#  250
#  537
#  235
#  176
#  174
#  225
#  261
#  232
# [torch.LongTensor of size 10]
# ,
#  11.3400
#  11.0543
#  10.6968
#   8.9613
#   7.9810
#   7.8145
#   7.4655
#   7.2392
#   6.3367
#   6.1474
# [torch.FloatTensor of size 10]
# )

# %%
# CAFFE result
top_inds = output_prob.argsort()[::-1][:10]  # reverse sort and take five largest items
print top_inds


print 'probabilities and labels:'
zip(output_prob[top_inds], labels[top_inds])
# Out:
# [249 248 250 235 537 174 261 225 232 244]
# probabilities and labels:
# [(12.144663, 'n02110063 malamute, malemute, Alaskan malamute'),
#  (11.67174, 'n02109961 Eskimo dog, husky'),
#  (11.052471, 'n02110185 Siberian husky'),
#  (9.0667601,
#   'n02106662 German shepherd, German shepherd dog, German police dog, alsatian'),
#  (8.5264196, 'n03218198 dogsled, dog sled, dog sleigh'),
#  (8.3197908, 'n02091467 Norwegian elkhound, elkhound'),
#  (7.6499395, 'n02112350 keeshond'),
#  (7.2292914, 'n02105162 malinois'),
#  (6.9224381, 'n02106166 Border collie'),
#  (6.6955643, 'n02108551 Tibetan mastiff')]
